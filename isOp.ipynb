# %%
a = 10
b = 15
a = b
c = 4
d = 7
c = d

# %%
a is b
# Out:
# True

# %%
a is c
# Out:
# False

# %%
a is a
# Out:
# True

# %%
b is a
# Out:
# True

# %%
c is b
# Out:
# False

# %%
b is b
# Out:
# True

# %%
d is d
# Out:
# True

# %%
d is c
# Out:
# True

# %%
c is d
# Out:
# True

# %%
a is d
# Out:
# False
