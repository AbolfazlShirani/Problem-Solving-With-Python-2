# %%
a = 10
b = 0
c = "abolfazl"
d = ""
e = ''
f = 'hello'
g = 17.6
h = 4
i = 8
j = 33

# %%
a and b
# Out:
# 0

# %%
a or b
# Out:
# 10

# %%
not b
# Out:
# True

# %%
not a
# Out:
# False

# %%
c and d
# Out:
# ''

# %%
c or d
# Out:
# 'abolfazl'

# %%
not c
# Out:
# False

# %%
d and e
# Out:
# ''

# %%
h and g
# Out:
# 17.6

# %%
g or h
# Out:
# 17.6
