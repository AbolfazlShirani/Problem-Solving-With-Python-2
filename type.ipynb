# %%
a = 1
b = 1.5
c = "abolfazl"
d = True
e = []
f = ()
g = {"ali":10}
h = 3+5j
i = None
j = {1,22,3}

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %%
type(d)
# Out:
# bool

# %%
type(e)
# Out:
# list

# %%
type(f)
# Out:
# tuple

# %%
type(g)
# Out:
# dict

# %%
type(h)
# Out:
# complex

# %%
type(i)
# Out:
# NoneType

# %%
type(j)
# Out:
# set
